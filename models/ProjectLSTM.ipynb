# %% [markdown]
# ## Importing needed required libraries, also using Tensorflow which is not included in conda you will need to pip install it prior to running this notebook
# ### creating df from github repositiory we have created

# %%
import pandas as pd
import numpy as np
import pandas as pd
import tensorflow as tf
import ssl
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error



ssl._create_default_https_context = ssl._create_unverified_context
df1 = pd.read_csv("https://raw.githubusercontent.com/LyJacky/stocks/4802f4e0f139ee0568afbad309086d90c78a53b7/all_stocks_5yr.csv")
# Out:
# 2023-11-16 18:53:14.452086: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### In the dataset each stock has 1259 days of stocks which is why we have picked the first 1259 days.

# %%
from preprocessing import apiCall
import sys

# Access the command-line arguments
if len(sys.argv) > 0:
    arg1 = sys.argv[1] 
    df2 = apiCall(arg1)
    df2 = df2.reset_index()['close']
else:
    df2 = apiCall("IBM")
    df2 = df2.reset_index()['close']
df2
# Out:
#        close
# 0      77.62
# 1      80.25
# 2      81.50
# 3      83.62
# 4      88.31
# ...      ...
# 6037  170.29
# 6038  170.77
# 6039  173.97
# 6040  177.57
# 6041  176.65
#
# [6042 rows x 1 columns]
# 0        96.75
# 1        94.81
# 2        94.37
# 3        91.56
# 4        90.25
#          ...
# 6037    142.63
# 6038    144.64
# 6039    145.40
# 6040    147.01
# 6041    147.90
# Name: close, Length: 6042, dtype: float64

# %%
plt.plot(df2)

# %%
df1 = df1.reset_index()['close']
# only for AAL stock
df1 = df1[0:1259]
df1
# Out:
# 0       14.75
# 1       14.46
# 2       14.27
# 3       14.66
# 4       13.99
#         ...
# 1254    53.88
# 1255    52.10
# 1256    49.76
# 1257    51.18
# 1258    51.40
# Name: close, Length: 1259, dtype: float64

# %% [markdown]
# ### Plotting the graph of the closing price vs the date(implied)
# ### Only using the closing price to predict the price, the x axis represents the days

# %%
plt.plot(df1)

# %% [markdown]
# ## Normalizing the data using MinMaxScaler to values between 0 and 1

# %%
# scales the close values between the values 0 and 1
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))
df1
# Out:
# array([[0.03806381],
#        [0.03168317],
#        [0.02750275],
#        ...,
#        [0.80836084],
#        [0.83960396],
#        [0.84444444]])

# %% [markdown]
# ## Making training and testing data, since we are dealing with stocks we must split them in a sequential way having the training data have data all before one of the testing data.
# ### The data will basically be partitioned into the first .65% being training and the other testing

# %%
# training size is the number of data we are going to use for the traning data
training_size=int(len(df1)*0.65)
# test_size is just the complement of training size.
test_size=len(df1)-training_size
# makes 2 new lists train_data and test_data which are both subsets of the df1
# train_data is going to be df1 from 0 to training size, and tet_data will be from training size to the rest of the data
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %% [markdown]
# ## Since we are going to deal with LSTM's the input must be a sequence. Hence all of our X_train and X_test will be a sequence of the price 100 days prior the current day
# ### The y train and test will jus tbe the stock of the day of

# %%
time_step = 100
X_train, y_train = [], []
for i in range(len(train_data)-time_step-1):
    a = train_data[i:(i+time_step), 0]   
    X_train.append(a)
    y_train.append(train_data[i + time_step, 0])


X_test, ytest = [], []
for i in range(len(test_data)-time_step-1):
    a = test_data[i:(i+time_step), 0]   
    X_test.append(a)
    ytest.append(test_data[i + time_step, 0])

# %% [markdown]
# ### Converting all of the lists intp np arrays in order to reshape the list in a later stage so that the keras libary has the proper inputs for the necessary functions

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
ytest = np.array(ytest)

# %%
X_train
# Out:
# array([[0.03806381, 0.03168317, 0.02750275, ..., 0.07480748, 0.08316832,
#         0.0750275 ],
#        [0.03168317, 0.02750275, 0.03608361, ..., 0.08316832, 0.0750275 ,
#         0.08206821],
#        [0.02750275, 0.03608361, 0.02134213, ..., 0.0750275 , 0.08206821,
#         0.0840484 ],
#        ...,
#        [0.67392739, 0.68360836, 0.63960396, ..., 0.47678768, 0.47106711,
#         0.47436744],
#        [0.68360836, 0.63960396, 0.63256326, ..., 0.47106711, 0.47436744,
#         0.44422442],
#        [0.63960396, 0.63256326, 0.65071507, ..., 0.47436744, 0.44422442,
#         0.43531353]])

# %% [markdown]
# ## Reshaping the list thanks to np arrays where the 3rd dim is the number of features

# %%
# last one says one feature, reshapes features so its a 3 dim and the last dim is the number of features
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# ## Importing proper libraries for LSTM and neural networks

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %% [markdown]
# ### Creating LSTM Model with one input layer, another 3 layers of 50 LSTM nodes (whenever we have an LSTM layer we must do return sequence since LSTM require sequences), hence for the last layer we must put return sequence false which is the default
# ### Training the LSTM Model with 100 epochs which represents the 100 days

# %%
# Building the LSTM model using keras
# input node is a sequence since LSTM accept sequences
model=Sequential()
# goes to a layer of 50 LSTM nodes which return a sequence
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
# goes to another layer of 50 LSTM nodes which return a sequence
model.add(LSTM(50,return_sequences=True))
# goes to the last layer of 50 LSTM node, and does not return a sequence since the next layer will be one node
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 9s 193ms/step - loss: 0.1378 - val_loss: 0.0059
# Epoch 2/100
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0148 - val_loss: 0.0063
# Epoch 3/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0076 - val_loss: 0.0123
# Epoch 4/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 5/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 6/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0032 - val_loss: 0.0044
# Epoch 7/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 8/100
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 9/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 10/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 11/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 12/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 13/100
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 14/100
# 12/12 [==============================] - 1s 96ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 15/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 16/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 17/100
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 18/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 19/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 20/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0026 - val_loss: 0.0043
# Epoch 21/100
# 12/12 [==============================] - 1s 97ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 22/100
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0029 - val_loss: 0.0043
# Epoch 23/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 24/100
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 25/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.0027 - val_loss: 0.0045
# Epoch 26/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 27/100
# 12/12 [==============================] - 1s 112ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 28/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 29/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 30/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 31/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 32/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 33/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 34/100
# 12/12 [==============================] - 1s 117ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 35/100
# 12/12 [==============================] - 1s 126ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 36/100
# 12/12 [==============================] - 1s 123ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 37/100
# 12/12 [==============================] - 1s 119ms/step - loss: 0.0023 - val_loss: 0.0045
# Epoch 38/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 39/100
# 12/12 [==============================] - 1s 117ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 40/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 41/100
# 12/12 [==============================] - 2s 149ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 42/100
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 43/100
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 44/100
# 12/12 [==============================] - 2s 131ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 45/100
# 12/12 [==============================] - 2s 146ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 46/100
# 12/12 [==============================] - 1s 118ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 47/100
# 12/12 [==============================] - 2s 142ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 48/100
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 49/100
# 12/12 [==============================] - 2s 123ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 50/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 51/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 52/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 53/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 54/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 55/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 56/100
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 57/100
# 12/12 [==============================] - 1s 121ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 58/100
# 12/12 [==============================] - 1s 118ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 59/100
# 12/12 [==============================] - 1s 126ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 60/100
# 12/12 [==============================] - 1s 122ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 61/100
# 12/12 [==============================] - 1s 111ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 62/100
# 12/12 [==============================] - 1s 119ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 63/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 64/100
# 12/12 [==============================] - 1s 124ms/step - loss: 0.0014 - val_loss: 9.5216e-04
# Epoch 65/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 66/100
# 12/12 [==============================] - 1s 122ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 67/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 68/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0012 - val_loss: 9.3365e-04
# Epoch 69/100
# 12/12 [==============================] - 1s 97ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 70/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 71/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 72/100
# 12/12 [==============================] - 1s 107ms/step - loss: 9.9610e-04 - val_loss: 8.2456e-04
# Epoch 73/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 74/100
# 12/12 [==============================] - 1s 108ms/step - loss: 9.6217e-04 - val_loss: 0.0010
# Epoch 75/100
# 12/12 [==============================] - 1s 126ms/step - loss: 9.4521e-04 - val_loss: 8.1936e-04
# Epoch 76/100
# 12/12 [==============================] - 2s 127ms/step - loss: 8.6366e-04 - val_loss: 0.0016
# Epoch 77/100
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0011 - val_loss: 7.2099e-04
# Epoch 78/100
# 12/12 [==============================] - 2s 135ms/step - loss: 9.8682e-04 - val_loss: 7.7528e-04
# Epoch 79/100
# 12/12 [==============================] - 2s 139ms/step - loss: 8.5409e-04 - val_loss: 0.0010
# Epoch 80/100
# 12/12 [==============================] - 1s 113ms/step - loss: 8.7815e-04 - val_loss: 8.5067e-04
# Epoch 81/100
# 12/12 [==============================] - 2s 130ms/step - loss: 8.9501e-04 - val_loss: 0.0012
# Epoch 82/100
# 12/12 [==============================] - 1s 114ms/step - loss: 8.4870e-04 - val_loss: 0.0010
# Epoch 83/100
# 12/12 [==============================] - 2s 130ms/step - loss: 8.4178e-04 - val_loss: 9.2960e-04
# Epoch 84/100
# 12/12 [==============================] - 2s 131ms/step - loss: 8.6444e-04 - val_loss: 9.7625e-04
# Epoch 85/100
# 12/12 [==============================] - 2s 142ms/step - loss: 8.2738e-04 - val_loss: 0.0011
# Epoch 86/100
# 12/12 [==============================] - 1s 117ms/step - loss: 8.0868e-04 - val_loss: 0.0012
# Epoch 87/100
# 12/12 [==============================] - 2s 139ms/step - loss: 8.5589e-04 - val_loss: 8.9052e-04
# Epoch 88/100
# 12/12 [==============================] - 2s 127ms/step - loss: 7.4553e-04 - val_loss: 7.7591e-04
# Epoch 89/100
# 12/12 [==============================] - 2s 127ms/step - loss: 7.7484e-04 - val_loss: 7.2957e-04
# Epoch 90/100
# 12/12 [==============================] - 1s 112ms/step - loss: 7.3795e-04 - val_loss: 0.0014
# Epoch 91/100
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0010 - val_loss: 6.9787e-04
# Epoch 92/100
# 12/12 [==============================] - 2s 147ms/step - loss: 9.3776e-04 - val_loss: 8.9607e-04
# Epoch 93/100
# 12/12 [==============================] - 2s 132ms/step - loss: 7.3998e-04 - val_loss: 0.0013
# Epoch 94/100
# 12/12 [==============================] - 2s 132ms/step - loss: 7.3125e-04 - val_loss: 5.9713e-04
# Epoch 95/100
# 12/12 [==============================] - 2s 162ms/step - loss: 6.8995e-04 - val_loss: 6.0506e-04
# Epoch 96/100
# 12/12 [==============================] - 2s 147ms/step - loss: 7.6091e-04 - val_loss: 8.1190e-04
# Epoch 97/100
# 12/12 [==============================] - 1s 120ms/step - loss: 7.7796e-04 - val_loss: 0.0010
# Epoch 98/100
# 12/12 [==============================] - 1s 110ms/step - loss: 8.0872e-04 - val_loss: 5.6004e-04
# Epoch 99/100
# 12/12 [==============================] - 1s 94ms/step - loss: 6.9573e-04 - val_loss: 6.1475e-04
# Epoch 100/100
# 12/12 [==============================] - 1s 100ms/step - loss: 7.3516e-04 - val_loss: 5.5126e-04

# %% [markdown]
# ### Predicting based on the trained model

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 23/23 [==============================] - 2s 19ms/step
# 11/11 [==============================] - 0s 20ms/step

# %%
test_predict
# Out:
# array([[0.5145245 ],
#        [0.5192239 ],
#        [0.53145754],
#        [0.5436231 ],
#        [0.55182344],
#        [0.55642766],
#        [0.5544456 ],
#        [0.55737686],
#        [0.55870086],
#        [0.55195713],
#        [0.5559516 ],
#        [0.562903  ],
#        [0.56742597],
#        [0.57416177],
#        [0.5899354 ],
#        [0.6055904 ],
#        [0.6090845 ],
#        [0.6030441 ],
#        [0.59411854],
#        [0.5854386 ],
#        [0.5850471 ],
#        [0.5912529 ],
#        [0.60236347],
#        [0.6057007 ],
#        [0.60167426],
#        [0.59336585],
#        [0.5893237 ],
#        [0.6031692 ],
#        [0.62408006],
#        [0.64437497],
#        [0.6546496 ],
#        [0.6595576 ],
#        [0.6642339 ],
#        [0.6782892 ],
#        [0.6900093 ],
#        [0.7053214 ],
#        [0.72068244],
#        [0.7279405 ],
#        [0.7275502 ],
#        [0.7265096 ],
#        [0.73111063],
#        [0.73488295],
#        [0.73967934],
#        [0.7398756 ],
#        [0.7317735 ],
#        [0.7266694 ],
#        [0.72371334],
#        [0.7292671 ],
#        [0.75644314],
#        [0.77796793],
#        [0.79780257],
#        [0.7905014 ],
#        [0.7733072 ],
#        [0.76249075],
#        [0.7644418 ],
#        [0.76569307],
#        [0.77305245],
#        [0.7866941 ],
#        [0.799313  ],
#        [0.79789835],
#        [0.78769755],
#        [0.7804014 ],
#        [0.7705289 ],
#        [0.7595695 ],
#        [0.7484664 ],
#        [0.7391154 ],
#        [0.73863864],
#        [0.7358315 ],
#        [0.7346463 ],
#        [0.7427779 ],
#        [0.7643206 ],
#        [0.7836721 ],
#        [0.78617805],
#        [0.7739934 ],
#        [0.752881  ],
#        [0.74581105],
#        [0.7471521 ],
#        [0.7572516 ],
#        [0.7574786 ],
#        [0.7566179 ],
#        [0.76040715],
#        [0.7801878 ],
#        [0.77582824],
#        [0.73948336],
#        [0.69989234],
#        [0.6785966 ],
#        [0.6763887 ],
#        [0.68498874],
#        [0.7031613 ],
#        [0.71670055],
#        [0.71946776],
#        [0.72575617],
#        [0.7334831 ],
#        [0.74574023],
#        [0.74728656],
#        [0.74935734],
#        [0.74708676],
#        [0.7425568 ],
#        [0.7385298 ],
#        [0.7327899 ],
#        [0.7269721 ],
#        [0.7259181 ],
#        [0.72878957],
#        [0.73271066],
#        [0.741697  ],
#        [0.7377175 ],
#        [0.7372244 ],
#        [0.72749364],
#        [0.71216327],
#        [0.7020774 ],
#        [0.68652016],
#        [0.6787649 ],
#        [0.666489  ],
#        [0.64609826],
#        [0.6375289 ],
#        [0.64035577],
#        [0.6433913 ],
#        [0.6433943 ],
#        [0.631008  ],
#        [0.6158138 ],
#        [0.61453915],
#        [0.62434614],
#        [0.6347113 ],
#        [0.6463083 ],
#        [0.6487084 ],
#        [0.648668  ],
#        [0.6462612 ],
#        [0.64461744],
#        [0.6319107 ],
#        [0.6207686 ],
#        [0.61991495],
#        [0.6262406 ],
#        [0.63726866],
#        [0.6588992 ],
#        [0.67839324],
#        [0.6824523 ],
#        [0.6829369 ],
#        [0.67983276],
#        [0.6810396 ],
#        [0.6915908 ],
#        [0.7023633 ],
#        [0.71846676],
#        [0.7328169 ],
#        [0.7378273 ],
#        [0.7150423 ],
#        [0.67602223],
#        [0.6442801 ],
#        [0.64725983],
#        [0.6685904 ],
#        [0.68754303],
#        [0.7002932 ],
#        [0.70827657],
#        [0.7287173 ],
#        [0.7499974 ],
#        [0.7539134 ],
#        [0.7392505 ],
#        [0.7296189 ],
#        [0.7315428 ],
#        [0.7209303 ],
#        [0.70417035],
#        [0.6983773 ],
#        [0.7109524 ],
#        [0.7313327 ],
#        [0.7462598 ],
#        [0.76164466],
#        [0.77768093],
#        [0.7799333 ],
#        [0.7769687 ],
#        [0.77978516],
#        [0.7893313 ],
#        [0.7996    ],
#        [0.8050129 ],
#        [0.8157043 ],
#        [0.8306433 ],
#        [0.8300513 ],
#        [0.813789  ],
#        [0.7989323 ],
#        [0.7935918 ],
#        [0.79338425],
#        [0.7923219 ],
#        [0.7991512 ],
#        [0.7924492 ],
#        [0.7843542 ],
#        [0.78595906],
#        [0.7887871 ],
#        [0.79080147],
#        [0.78852344],
#        [0.79162824],
#        [0.7997951 ],
#        [0.81226045],
#        [0.8210326 ],
#        [0.83093643],
#        [0.8444303 ],
#        [0.86229   ],
#        [0.87018806],
#        [0.8586722 ],
#        [0.8645625 ],
#        [0.87968177],
#        [0.89439297],
#        [0.89806724],
#        [0.88809466],
#        [0.87276536],
#        [0.861831  ],
#        [0.8554867 ],
#        [0.8484953 ],
#        [0.8381248 ],
#        [0.83542955],
#        [0.82884395],
#        [0.8270835 ],
#        [0.8284912 ],
#        [0.8357035 ],
#        [0.835857  ],
#        [0.8319222 ],
#        [0.83042824],
#        [0.8287123 ],
#        [0.8213721 ],
#        [0.8085926 ],
#        [0.79150635],
#        [0.77884823],
#        [0.7790832 ],
#        [0.7826681 ],
#        [0.7836885 ],
#        [0.7605976 ],
#        [0.7312502 ],
#        [0.71625316],
#        [0.7132593 ],
#        [0.7032467 ],
#        [0.6830823 ],
#        [0.68696266],
#        [0.7008018 ],
#        [0.7073371 ],
#        [0.70321774],
#        [0.698916  ],
#        [0.70197886],
#        [0.69553417],
#        [0.68823665],
#        [0.68062663],
#        [0.6739308 ],
#        [0.68944955],
#        [0.7149434 ],
#        [0.7385989 ],
#        [0.7430148 ],
#        [0.73294693],
#        [0.7155645 ],
#        [0.6954355 ],
#        [0.6924136 ],
#        [0.7085023 ],
#        [0.7334337 ],
#        [0.7562819 ],
#        [0.76627773],
#        [0.75862956],
#        [0.751693  ],
#        [0.75053096],
#        [0.75507516],
#        [0.7846999 ],
#        [0.8169404 ],
#        [0.831609  ],
#        [0.836461  ],
#        [0.82985175],
#        [0.84362483],
#        [0.862027  ],
#        [0.8703479 ],
#        [0.86994815],
#        [0.86307704],
#        [0.8558961 ],
#        [0.85305667],
#        [0.84955645],
#        [0.85150576],
#        [0.8469358 ],
#        [0.85014385],
#        [0.8480324 ],
#        [0.8201456 ],
#        [0.78324395],
#        [0.7595803 ],
#        [0.7504974 ],
#        [0.760519  ],
#        [0.76961124],
#        [0.7721155 ],
#        [0.77010816],
#        [0.7570957 ],
#        [0.74286264],
#        [0.72954184],
#        [0.7224594 ],
#        [0.7205178 ],
#        [0.7216528 ],
#        [0.7350985 ],
#        [0.7531953 ],
#        [0.7615139 ],
#        [0.7624073 ],
#        [0.76824844],
#        [0.77503866],
#        [0.7775681 ],
#        [0.7752657 ],
#        [0.77926505],
#        [0.78617287],
#        [0.8022504 ],
#        [0.8027526 ],
#        [0.8021663 ],
#        [0.7996767 ],
#        [0.79903376],
#        [0.81197757],
#        [0.82777834],
#        [0.8389886 ],
#        [0.8348363 ],
#        [0.82170033],
#        [0.8132543 ],
#        [0.8204166 ],
#        [0.8360612 ],
#        [0.8466856 ],
#        [0.85336596],
#        [0.86379623],
#        [0.8698428 ],
#        [0.8726008 ],
#        [0.8686457 ],
#        [0.8641434 ],
#        [0.85841775],
#        [0.864282  ],
#        [0.8675283 ],
#        [0.86984223],
#        [0.8710579 ],
#        [0.8663911 ],
#        [0.8607315 ],
#        [0.87443167],
#        [0.91665965],
#        [0.9700014 ],
#        [0.99503964],
#        [0.9938941 ],
#        [0.98550457],
#        [0.97803354],
#        [0.97631514],
#        [0.9809138 ],
#        [0.95121896],
#        [0.90300286],
#        [0.87643677],
#        [0.87259245],
#        [0.87867   ],
#        [0.9015339 ],
#        [0.91577244],
#        [0.8984478 ],
#        [0.85136807]], dtype=float32)

# %% [markdown]
# ### Scaling the results back to the original

# %%
#  tranforms the scaled values back to the original
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
# y_train=scaler.inverse_transform(y_train)
# ytest=scaler.inverse_transform(ytest)

# %%
ytest
# Out:
# array([0.5190319 , 0.5430143 , 0.54147415, 0.54675468, 0.55335534,
#        0.54367437, 0.56919692, 0.5540154 , 0.5359736 , 0.57689769,
#        0.56391639, 0.56237624, 0.57931793, 0.60748075, 0.60660066,
#        0.59141914, 0.58987899, 0.58679868, 0.57865787, 0.59163916,
#        0.59493949, 0.60682068, 0.58921892, 0.58723872, 0.579978  ,
#        0.58789879, 0.62640264, 0.6310231 , 0.64664466, 0.64422442,
#        0.65808581, 0.66842684, 0.69834983, 0.69152915, 0.72189219,
#        0.73135314, 0.72739274, 0.72739274, 0.73311331, 0.74367437,
#        0.73663366, 0.74521452, 0.73531353, 0.72013201, 0.72783278,
#        0.71947195, 0.73509351, 0.78393839, 0.77073707, 0.80572057,
#        0.76061606, 0.76611661, 0.76787679, 0.77623762, 0.76149615,
#        0.78239824, 0.79647965, 0.8019802 , 0.78481848, 0.78019802,
#        0.78305831, 0.76237624, 0.75313531, 0.74081408, 0.73223322,
#        0.7410341 , 0.72321232, 0.73025303, 0.74939494, 0.78019802,
#        0.78371837, 0.77183718, 0.76193619, 0.74213421, 0.76171617,
#        0.75335534, 0.76963696, 0.74631463, 0.75951595, 0.76765677,
#        0.80462046, 0.74653465, 0.70143014, 0.68712871, 0.68272827,
#        0.68184818, 0.6860286 , 0.71023102, 0.70737074, 0.7049505 ,
#        0.73223322, 0.73553355, 0.75665567, 0.73817382, 0.75951595,
#        0.7469747 , 0.74565457, 0.74345435, 0.73267327, 0.72783278,
#        0.73179318, 0.73267327, 0.73355336, 0.74961496, 0.71947195,
#        0.74367437, 0.71045105, 0.70011001, 0.70121012, 0.66688669,
#        0.67942794, 0.64576458, 0.62024202, 0.63960396, 0.64048405,
#        0.63146315, 0.6310231 , 0.60286029, 0.60132013, 0.62464246,
#        0.63168317, 0.63190319, 0.65082508, 0.63674367, 0.64950495,
#        0.64422442, 0.64752475, 0.61342134, 0.62244224, 0.63146315,
#        0.63344334, 0.64466447, 0.68008801, 0.68074807, 0.66732673,
#        0.68668867, 0.67744774, 0.69042904, 0.70847085, 0.70693069,
#        0.73531353, 0.73905391, 0.73443344, 0.68118812, 0.65126513,
#        0.63938394, 0.67876788, 0.67986799, 0.67964796, 0.69284928,
#        0.70231023, 0.74939494, 0.75423542, 0.73751375, 0.72189219,
#        0.74059406, 0.74631463, 0.70187019, 0.69592959, 0.70847085,
#        0.73025303, 0.74015402, 0.74257426, 0.77007701, 0.78591859,
#        0.76875688, 0.77865787, 0.79273927, 0.80308031, 0.80792079,
#        0.80792079, 0.83256326, 0.84510451, 0.81958196, 0.80220022,
#        0.80154015, 0.80022002, 0.79405941, 0.7870187 , 0.80616062,
#        0.77029703, 0.77909791, 0.7909791 , 0.78349835, 0.78679868,
#        0.78063806, 0.79713971, 0.80528053, 0.82068207, 0.82222222,
#        0.84136414, 0.85874587, 0.88030803, 0.87216722, 0.84906491,
#        0.89724972, 0.89746975, 0.90649065, 0.89878988, 0.88294829,
#        0.87106711, 0.86512651, 0.85566557, 0.84180418, 0.82706271,
#        0.83586359, 0.81364136, 0.82442244, 0.82332233, 0.8369637 ,
#        0.82354235, 0.82574257, 0.83124312, 0.82640264, 0.81364136,
#        0.80044004, 0.78173817, 0.77733773, 0.78745875, 0.78107811,
#        0.77865787, 0.72629263, 0.71573157, 0.71925193, 0.71265127,
#        0.6809681 , 0.65786579, 0.70913091, 0.70253025, 0.69394939,
#        0.68866887, 0.69790979, 0.71045105, 0.67986799, 0.68844884,
#        0.67810781, 0.67282728, 0.72255226, 0.7320132 , 0.74763476,
#        0.72981298, 0.72563256, 0.71045105, 0.689989  , 0.71287129,
#        0.7320132 , 0.7489549 , 0.7630363 , 0.76039604, 0.74433443,
#        0.75841584, 0.75841584, 0.76369637, 0.82486249, 0.82970297,
#        0.8259626 , 0.84224422, 0.82684268, 0.88030803, 0.87590759,
#        0.87194719, 0.8730473 , 0.86358636, 0.85918592, 0.85830583,
#        0.84686469, 0.85610561, 0.83520352, 0.85654565, 0.83608361,
#        0.78305831, 0.759956  , 0.75313531, 0.74367437, 0.76611661,
#        0.75555556, 0.75753575, 0.75885589, 0.73575358, 0.73377338,
#        0.72057206, 0.72167217, 0.71991199, 0.72145215, 0.75181518,
#        0.76259626, 0.75621562, 0.76281628, 0.78393839, 0.78415842,
#        0.7819582 , 0.77887789, 0.79647965, 0.79713971, 0.82442244,
#        0.79163916, 0.81210121, 0.8019802 , 0.80506051, 0.8330033 ,
#        0.83608361, 0.84224422, 0.8239824 , 0.81562156, 0.81826183,
#        0.8369637 , 0.84642464, 0.84532453, 0.85588559, 0.8750275 ,
#        0.87062706, 0.87634763, 0.86644664, 0.86776678, 0.85830583,
#        0.87942794, 0.86512651, 0.87238724, 0.87194719, 0.86050605,
#        0.85940594, 0.89680968, 0.95489549, 1.        , 0.98921892,
#        0.99317932, 0.99713971, 0.9909791 , 0.99185919, 0.9960396 ,
#        0.9190319 , 0.88074807, 0.88118812, 0.87260726, 0.87062706,
#        0.90869087, 0.8990099 , 0.85984598, 0.80836084, 0.83960396])

# %%
# changes the y_train and ytest values back to the original values, I had to transpose [y_train] and [x_train] so it
# would be the same dimensions as the test_predict and train_predict
y_train=scaler.inverse_transform(np.transpose([y_train]))
ytest=scaler.inverse_transform(np.transpose([ytest]))

# %%
print(ytest.shape)
print(test_predict.shape)
print(y_train.shape)
print(train_predict.shape)
# Out:
# (340, 1)
# (340, 1)
# (717, 1)
# (717, 1)

# %% [markdown]
# ## Displaying RMSE of testing and training data

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 1.1434214654490833

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 1.0671202986236095

# %% [markdown]
# ### Plotting the predictions along with the original graph of the closing cost

# %%
look_back=100

trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

testPredictPlot = np.empty_like(df1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict

plt.plot(scaler.inverse_transform(df1),label = "Actual values")
plt.plot(trainPredictPlot,label = "Training Prediction")
plt.plot(testPredictPlot, label = "Testing Prediction")
plt.legend()
plt.show()

# %%
model.save("models/LSTM")
# Out:
# INFO:tensorflow:Assets written to: models/LSTM/assets
# INFO:tensorflow:Assets written to: models/LSTM/assets

# %%
import pickle
with open('./LSTMHistory.pickle', 'wb') as file_pi:
    pickle.dump(model, file_pi)

# %%
with open('./LSTMHistory.pickle', 'rb') as file_pi:
    pickled_history = pickle.load(file_pi)

# %%
pickled_history.predict(X_test)
# Out:
# 11/11 [==============================] - 2s 20ms/step
# array([[0.5145245 ],
#        [0.5192239 ],
#        [0.53145754],
#        [0.5436231 ],
#        [0.55182344],
#        [0.55642766],
#        [0.5544456 ],
#        [0.55737686],
#        [0.55870086],
#        [0.55195713],
#        [0.5559516 ],
#        [0.562903  ],
#        [0.56742597],
#        [0.57416177],
#        [0.5899354 ],
#        [0.6055904 ],
#        [0.6090845 ],
#        [0.6030441 ],
#        [0.59411854],
#        [0.5854386 ],
#        [0.5850471 ],
#        [0.5912529 ],
#        [0.60236347],
#        [0.6057007 ],
#        [0.60167426],
#        [0.59336585],
#        [0.5893237 ],
#        [0.6031692 ],
#        [0.62408006],
#        [0.64437497],
#        [0.6546496 ],
#        [0.6595576 ],
#        [0.6642339 ],
#        [0.6782892 ],
#        [0.6900093 ],
#        [0.7053214 ],
#        [0.72068244],
#        [0.7279405 ],
#        [0.7275502 ],
#        [0.7265096 ],
#        [0.73111063],
#        [0.73488295],
#        [0.73967934],
#        [0.7398756 ],
#        [0.7317735 ],
#        [0.7266694 ],
#        [0.72371334],
#        [0.7292671 ],
#        [0.75644314],
#        [0.77796793],
#        [0.79780257],
#        [0.7905014 ],
#        [0.7733072 ],
#        [0.76249075],
#        [0.7644418 ],
#        [0.76569307],
#        [0.77305245],
#        [0.7866941 ],
#        [0.799313  ],
#        [0.79789835],
#        [0.78769755],
#        [0.7804014 ],
#        [0.7705289 ],
#        [0.7595695 ],
#        [0.7484664 ],
#        [0.7391154 ],
#        [0.73863864],
#        [0.7358315 ],
#        [0.7346463 ],
#        [0.7427779 ],
#        [0.7643206 ],
#        [0.7836721 ],
#        [0.78617805],
#        [0.7739934 ],
#        [0.752881  ],
#        [0.74581105],
#        [0.7471521 ],
#        [0.7572516 ],
#        [0.7574786 ],
#        [0.7566179 ],
#        [0.76040715],
#        [0.7801878 ],
#        [0.77582824],
#        [0.73948336],
#        [0.69989234],
#        [0.6785966 ],
#        [0.6763887 ],
#        [0.68498874],
#        [0.7031613 ],
#        [0.71670055],
#        [0.71946776],
#        [0.72575617],
#        [0.7334831 ],
#        [0.74574023],
#        [0.74728656],
#        [0.74935734],
#        [0.74708676],
#        [0.7425568 ],
#        [0.7385298 ],
#        [0.7327899 ],
#        [0.7269721 ],
#        [0.7259181 ],
#        [0.72878957],
#        [0.73271066],
#        [0.741697  ],
#        [0.7377175 ],
#        [0.7372244 ],
#        [0.72749364],
#        [0.71216327],
#        [0.7020774 ],
#        [0.68652016],
#        [0.6787649 ],
#        [0.666489  ],
#        [0.64609826],
#        [0.6375289 ],
#        [0.64035577],
#        [0.6433913 ],
#        [0.6433943 ],
#        [0.631008  ],
#        [0.6158138 ],
#        [0.61453915],
#        [0.62434614],
#        [0.6347113 ],
#        [0.6463083 ],
#        [0.6487084 ],
#        [0.648668  ],
#        [0.6462612 ],
#        [0.64461744],
#        [0.6319107 ],
#        [0.6207686 ],
#        [0.61991495],
#        [0.6262406 ],
#        [0.63726866],
#        [0.6588992 ],
#        [0.67839324],
#        [0.6824523 ],
#        [0.6829369 ],
#        [0.67983276],
#        [0.6810396 ],
#        [0.6915908 ],
#        [0.7023633 ],
#        [0.71846676],
#        [0.7328169 ],
#        [0.7378273 ],
#        [0.7150423 ],
#        [0.67602223],
#        [0.6442801 ],
#        [0.64725983],
#        [0.6685904 ],
#        [0.68754303],
#        [0.7002932 ],
#        [0.70827657],
#        [0.7287173 ],
#        [0.7499974 ],
#        [0.7539134 ],
#        [0.7392505 ],
#        [0.7296189 ],
#        [0.7315428 ],
#        [0.7209303 ],
#        [0.70417035],
#        [0.6983773 ],
#        [0.7109524 ],
#        [0.7313327 ],
#        [0.7462598 ],
#        [0.76164466],
#        [0.77768093],
#        [0.7799333 ],
#        [0.7769687 ],
#        [0.77978516],
#        [0.7893313 ],
#        [0.7996    ],
#        [0.8050129 ],
#        [0.8157043 ],
#        [0.8306433 ],
#        [0.8300513 ],
#        [0.813789  ],
#        [0.7989323 ],
#        [0.7935918 ],
#        [0.79338425],
#        [0.7923219 ],
#        [0.7991512 ],
#        [0.7924492 ],
#        [0.7843542 ],
#        [0.78595906],
#        [0.7887871 ],
#        [0.79080147],
#        [0.78852344],
#        [0.79162824],
#        [0.7997951 ],
#        [0.81226045],
#        [0.8210326 ],
#        [0.83093643],
#        [0.8444303 ],
#        [0.86229   ],
#        [0.87018806],
#        [0.8586722 ],
#        [0.8645625 ],
#        [0.87968177],
#        [0.89439297],
#        [0.89806724],
#        [0.88809466],
#        [0.87276536],
#        [0.861831  ],
#        [0.8554867 ],
#        [0.8484953 ],
#        [0.8381248 ],
#        [0.83542955],
#        [0.82884395],
#        [0.8270835 ],
#        [0.8284912 ],
#        [0.8357035 ],
#        [0.835857  ],
#        [0.8319222 ],
#        [0.83042824],
#        [0.8287123 ],
#        [0.8213721 ],
#        [0.8085926 ],
#        [0.79150635],
#        [0.77884823],
#        [0.7790832 ],
#        [0.7826681 ],
#        [0.7836885 ],
#        [0.7605976 ],
#        [0.7312502 ],
#        [0.71625316],
#        [0.7132593 ],
#        [0.7032467 ],
#        [0.6830823 ],
#        [0.68696266],
#        [0.7008018 ],
#        [0.7073371 ],
#        [0.70321774],
#        [0.698916  ],
#        [0.70197886],
#        [0.69553417],
#        [0.68823665],
#        [0.68062663],
#        [0.6739308 ],
#        [0.68944955],
#        [0.7149434 ],
#        [0.7385989 ],
#        [0.7430148 ],
#        [0.73294693],
#        [0.7155645 ],
#        [0.6954355 ],
#        [0.6924136 ],
#        [0.7085023 ],
#        [0.7334337 ],
#        [0.7562819 ],
#        [0.76627773],
#        [0.75862956],
#        [0.751693  ],
#        [0.75053096],
#        [0.75507516],
#        [0.7846999 ],
#        [0.8169404 ],
#        [0.831609  ],
#        [0.836461  ],
#        [0.82985175],
#        [0.84362483],
#        [0.862027  ],
#        [0.8703479 ],
#        [0.86994815],
#        [0.86307704],
#        [0.8558961 ],
#        [0.85305667],
#        [0.84955645],
#        [0.85150576],
#        [0.8469358 ],
#        [0.85014385],
#        [0.8480324 ],
#        [0.8201456 ],
#        [0.78324395],
#        [0.7595803 ],
#        [0.7504974 ],
#        [0.760519  ],
#        [0.76961124],
#        [0.7721155 ],
#        [0.77010816],
#        [0.7570957 ],
#        [0.74286264],
#        [0.72954184],
#        [0.7224594 ],
#        [0.7205178 ],
#        [0.7216528 ],
#        [0.7350985 ],
#        [0.7531953 ],
#        [0.7615139 ],
#        [0.7624073 ],
#        [0.76824844],
#        [0.77503866],
#        [0.7775681 ],
#        [0.7752657 ],
#        [0.77926505],
#        [0.78617287],
#        [0.8022504 ],
#        [0.8027526 ],
#        [0.8021663 ],
#        [0.7996767 ],
#        [0.79903376],
#        [0.81197757],
#        [0.82777834],
#        [0.8389886 ],
#        [0.8348363 ],
#        [0.82170033],
#        [0.8132543 ],
#        [0.8204166 ],
#        [0.8360612 ],
#        [0.8466856 ],
#        [0.85336596],
#        [0.86379623],
#        [0.8698428 ],
#        [0.8726008 ],
#        [0.8686457 ],
#        [0.8641434 ],
#        [0.85841775],
#        [0.864282  ],
#        [0.8675283 ],
#        [0.86984223],
#        [0.8710579 ],
#        [0.8663911 ],
#        [0.8607315 ],
#        [0.87443167],
#        [0.91665965],
#        [0.9700014 ],
#        [0.99503964],
#        [0.9938941 ],
#        [0.98550457],
#        [0.97803354],
#        [0.97631514],
#        [0.9809138 ],
#        [0.95121896],
#        [0.90300286],
#        [0.87643677],
#        [0.87259245],
#        [0.87867   ],
#        [0.9015339 ],
#        [0.91577244],
#        [0.8984478 ],
#        [0.85136807]], dtype=float32)

# %%
X_test
# Out:
# array([[[0.45654565],
#         [0.43652365],
#         [0.40286029],
#         ...,
#         [0.50561056],
#         [0.50209021],
#         [0.50165017]],
#
#        [[0.43652365],
#         [0.40286029],
#         [0.40682068],
#         ...,
#         [0.50209021],
#         [0.50165017],
#         [0.5190319 ]],
#
#        [[0.40286029],
#         [0.40682068],
#         [0.42024202],
#         ...,
#         [0.50165017],
#         [0.5190319 ],
#         [0.5430143 ]],
#
#        ...,
#
#        [[0.72255226],
#         [0.7320132 ],
#         [0.74763476],
#         ...,
#         [0.87062706],
#         [0.90869087],
#         [0.8990099 ]],
#
#        [[0.7320132 ],
#         [0.74763476],
#         [0.72981298],
#         ...,
#         [0.90869087],
#         [0.8990099 ],
#         [0.85984598]],
#
#        [[0.74763476],
#         [0.72981298],
#         [0.72563256],
#         ...,
#         [0.8990099 ],
#         [0.85984598],
#         [0.80836084]]])

# %%
x = X_test[-1]
x.shape
# Out:
# (100, 1)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 100, 1)

# %%
predict = pickled_history.predict(x)
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
scaler.inverse_transform(predict)
# Out:
# array([[51.714672]], dtype=float32)
